# %%
from dataquality_leticia.dataquality import RelatorioCSV
relatorio = RelatorioCSV('Forbes_Richest_Atheletes_1990_2020.csv')

# %% [markdown]
# Chama o relatório completo do arquivo, contendo primeiro uma análise geral e depois análise coluna por coluna

# %%
relatorio.relatorio_completo()
# Out:
# # Índice
# ## Índice Geral
# - [Início do Arquivo](#início-do-arquivo)
# - [Final do Arquivo](#final-do-arquivo)
# - [Quantidade de Linhas/Colunas](#quantidade-de-linhascolunas)
# - [Nome das Colunas](#nome-das-colunas)
# - [Relatório Estatístico Geral](#relatório-estatístico-geral)
# - [Quantidade de Registros Duplicados](#quantidade-de-registros-duplicados)
# - [Matriz de Correlação das Colunas Numéricas](#matriz-de-correlacao-das-colunas-numericas)
#  ==*==*==*== Início do Arquivo ==*==*==*==
# ## Início do Arquivo
#    S.NO               Name Nationality  Current Rank Previous Year Rank  \
# 0     1         Mike Tyson         USA             1                NaN
# 1     2     Buster Douglas         USA             2                NaN
# 2     3  Sugar Ray Leonard         USA             3                NaN
# 3     4       Ayrton Senna      Brazil             4                NaN
# 4     5        Alain Prost      France             5                NaN
#
#          Sport  Year  earnings ($ million)
# 0       boxing  1990                  28.6
# 1       boxing  1990                  26.0
# 2       boxing  1990                  13.0
# 3  auto racing  1990                  10.0
# 4  auto racing  1990                   9.0
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Final do Arquivo ==*==*==*==
# ## Final do Arquivo
#      S.NO           Name Nationality  Current Rank Previous Year Rank  \
# 296   297  Stephen Curry         USA             6                  9
# 297   298   Kevin Durant         USA             7                 10
# 298   299    Tiger Woods         USA             8                 11
# 299   300   Kirk Cousins         USA             9               >100
# 300   301   Carson Wentz         USA            10               >100
#
#                  Sport  Year  earnings ($ million)
# 296         Basketball  2020                  74.4
# 297         Basketball  2020                  63.9
# 298               Golf  2020                  62.3
# 299  American Football  2020                  60.5
# 300  American Football  2020                  59.1
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Quantidade de Linhas/Colunas ==*==*==*==
# ## Quantidade de Linhas/Colunas
# (301, 8)
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Nome das Colunas ==*==*==*==
#       Nomes das Colunas
# 0                  S.NO
# 1                  Name
# 2           Nationality
# 3          Current Rank
# 4    Previous Year Rank
# 5                 Sport
# 6                  Year
# 7  earnings ($ million)
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Relatório Estatístico Geral ==*==*==*==
#              S.NO  Current Rank         Year  earnings ($ million)
# count  301.000000    301.000000   301.000000            301.000000
# mean   151.000000      5.448505  2005.122924             45.516279
# std     87.035433      2.850995     9.063563             33.525337
# min      1.000000      1.000000  1990.000000              8.100000
# 25%     76.000000      3.000000  1997.000000             24.000000
# 50%    151.000000      5.000000  2005.000000             39.000000
# 75%    226.000000      8.000000  2013.000000             59.400000
# max    301.000000     10.000000  2020.000000            300.000000
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Quantidade de Registros Duplicados ==*==*==*==
#
#  0
#
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Matriz de Correlação das Colunas Numéricas ==*==*==*==
#
#                            S.NO  Current Rank      Year  earnings ($ million)
# S.NO                  1.000000      0.034739  0.999090              0.641399
# Current Rank          0.034739      1.000000  0.001600             -0.449052
# Year                  0.999090      0.001600  1.000000              0.653866
# earnings ($ million)  0.641399     -0.449052  0.653866              1.000000
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Relatório da Coluna: S.NO  ==*==*==*==
#
#
# Tipo: int64
# Valores nulos: 0
# valores únicos: 301
# Distribuição percentual de valores nulos: 0.00%
# Distribuição percentual dos valores únicos: 100.00%
#
# Possível coluna de índice, todos os valores são únicos.
#
# Estatísticas Descritivas
#              S.NO
# count  301.000000
# mean   151.000000
# std     87.035433
# min      1.000000
# 25%     76.000000
# 50%    151.000000
# 75%    226.000000
# max    301.000000
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Relatório da Coluna: Name  ==*==*==*==
#
#
# Tipo: object
# Valores nulos: 0
# valores únicos: 82
# Distribuição percentual de valores nulos: 0.00%
# Distribuição percentual dos valores únicos: 27.24%
#
#
# Listagem dos valores únicos e quantas vezes aparecem
#                     count
# Name
# Tiger Woods            19
# Michael Jordan         19
# Kobe Bryant            14
# LeBron James           13
# Michael Schumacher     13
# ...                   ...
# Tom Brady               1
# Michael Moorer          1
# Dale Earnhardt Jr.      1
# Greg Norman             1
# Carson Wentz            1
#
# [82 rows x 1 columns]
# Distribuição dos valores por percentual:
#                     Contagem  Percentual (%)
# Name
# Tiger Woods               19        6.312292
# Michael Jordan            19        6.312292
# Kobe Bryant               14        4.651163
# LeBron James              13        4.318937
# Michael Schumacher        13        4.318937
# ...                      ...             ...
# Tom Brady                  1        0.332226
# Michael Moorer             1        0.332226
# Dale Earnhardt Jr.         1        0.332226
# Greg Norman                1        0.332226
# Carson Wentz               1        0.332226
#
# [82 rows x 2 columns]
# Estatísticas Descritivas
#                Name
# count           301
# unique           82
# top     Tiger Woods
# freq             19
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Relatório da Coluna: Nationality  ==*==*==*==
#
#
# Tipo: object
# Valores nulos: 0
# valores únicos: 22
# Distribuição percentual de valores nulos: 0.00%
# Distribuição percentual dos valores únicos: 7.31%
#
#
# Listagem dos valores únicos e quantas vezes aparecem
#                   count
# Nationality
# USA                 206
# UK                   13
# Germany              13
# Switzerland          12
# Portugal             10
# Brazil                9
# Argentina             9
# Canada                6
# Italy                 4
# Finland               3
# France                3
# Philippines           3
# Russia                1
# Australia             1
# Dominican             1
# Austria               1
# Filipino              1
# Spain                 1
# Serbia                1
# Northern Ireland      1
# Ireland               1
# Mexico                1
# Distribuição dos valores por percentual:
#                   Contagem  Percentual (%)
# Nationality
# USA                    206       68.438538
# UK                      13        4.318937
# Germany                 13        4.318937
# Switzerland             12        3.986711
# Portugal                10        3.322259
# Brazil                   9        2.990033
# Argentina                9        2.990033
# Canada                   6        1.993355
# Italy                    4        1.328904
# Finland                  3        0.996678
# France                   3        0.996678
# Philippines              3        0.996678
# Russia                   1        0.332226
# Australia                1        0.332226
# Dominican                1        0.332226
# Austria                  1        0.332226
# Filipino                 1        0.332226
# Spain                    1        0.332226
# Serbia                   1        0.332226
# Northern Ireland         1        0.332226
# Ireland                  1        0.332226
# Mexico                   1        0.332226
# Estatísticas Descritivas
#        Nationality
# count          301
# unique          22
# top            USA
# freq           206
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Relatório da Coluna: Current Rank  ==*==*==*==
#
#
# Tipo: int64
# Valores nulos: 0
# valores únicos: 10
# Distribuição percentual de valores nulos: 0.00%
# Distribuição percentual dos valores únicos: 3.32%
#
#
# Listagem dos valores únicos e quantas vezes aparecem
#               count
# Current Rank
# 9                34
# 2                32
# 5                32
# 6                32
# 1                30
# 3                30
# 8                30
# 4                28
# 7                28
# 10               25
# Distribuição dos valores por percentual:
#               Contagem  Percentual (%)
# Current Rank
# 9                   34       11.295681
# 2                   32       10.631229
# 5                   32       10.631229
# 6                   32       10.631229
# 1                   30        9.966777
# 3                   30        9.966777
# 8                   30        9.966777
# 4                   28        9.302326
# 7                   28        9.302326
# 10                  25        8.305648
# Estatísticas Descritivas
#        Current Rank
# count    301.000000
# mean       5.448505
# std        2.850995
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        8.000000
# max       10.000000
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Relatório da Coluna: Previous Year Rank  ==*==*==*==
#
#
# Tipo: object
# Valores nulos: 24
# valores únicos: 36
# Distribuição percentual de valores nulos: 7.97%
# Distribuição percentual dos valores únicos: 11.96%
#
#
# Listagem dos valores únicos e quantas vezes aparecem
#                     count
# Previous Year Rank
# >10                    36
# 1                      25
# 5                      21
# 3                      21
# 2                      20
# 6                      18
# 7                      17
# 4                      17
# 8                      14
# 9                      13
# 10                      8
# 11                      6
# >100                    6
# >40                     6
# 13                      4
# 12                      4
# not ranked              4
# >20                     4
# 17                      3
# 19                      3
# ?                       3
# 20                      3
# 18                      2
# 24                      2
# ??                      2
# 14                      2
# 15                      2
# 30                      2
# >30                     2
# 26                      1
# none                    1
# 38                      1
# 40                      1
# 21                      1
# >14                     1
# 22                      1
# Distribuição dos valores por percentual:
#                     Contagem  Percentual (%)
# Previous Year Rank
# >10                       36       11.960133
# 1                         25        8.305648
# NaN                       24        7.973422
# 5                         21        6.976744
# 3                         21        6.976744
# 2                         20        6.644518
# 6                         18        5.980066
# 4                         17        5.647841
# 7                         17        5.647841
# 8                         14        4.651163
# 9                         13        4.318937
# 10                         8        2.657807
# 11                         6        1.993355
# >100                       6        1.993355
# >40                        6        1.993355
# 13                         4        1.328904
# not ranked                 4        1.328904
# >20                        4        1.328904
# 12                         4        1.328904
# 17                         3        0.996678
# ?                          3        0.996678
# 20                         3        0.996678
# 19                         3        0.996678
# 24                         2        0.664452
# 18                         2        0.664452
# 30                         2        0.664452
# 14                         2        0.664452
# 15                         2        0.664452
# >30                        2        0.664452
# ??                         2        0.664452
# 26                         1        0.332226
# none                       1        0.332226
# 38                         1        0.332226
# 22                         1        0.332226
# 40                         1        0.332226
# 21                         1        0.332226
# >14                        1        0.332226
# Estatísticas Descritivas
#        Previous Year Rank
# count                 277
# unique                 36
# top                   >10
# freq                   36
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Relatório da Coluna: Sport  ==*==*==*==
#
#
# Tipo: object
# Valores nulos: 0
# valores únicos: 29
# Distribuição percentual de valores nulos: 0.00%
# Distribuição percentual dos valores únicos: 9.63%
#
#
# Listagem dos valores únicos e quantas vezes aparecem
#                               count
# Sport
# Basketball                       54
# Boxing                           29
# basketball                       27
# Golf                             24
# Soccer                           22
# golf                             20
# Tennis                           18
# boxing                           17
# American Football                17
# soccer                           11
# Auto Racing                      10
# F1 racing                         8
# auto racing                       7
# tennis                            5
# F1 Motorsports                    5
# motorcycle gp                     4
# NFL                               3
# Baseball                          3
# NASCAR                            3
# baseball                          3
# Ice Hockey                        2
# Auto Racing (Nascar)              2
# cycling                           1
# American Football / Baseball      1
# Hockey                            1
# ice hockey                        1
# NBA                               1
# Auto racing                       1
# MMA                               1
# Distribuição dos valores por percentual:
#                               Contagem  Percentual (%)
# Sport
# Basketball                          54       17.940199
# Boxing                              29        9.634551
# basketball                          27        8.970100
# Golf                                24        7.973422
# Soccer                              22        7.308970
# golf                                20        6.644518
# Tennis                              18        5.980066
# boxing                              17        5.647841
# American Football                   17        5.647841
# soccer                              11        3.654485
# Auto Racing                         10        3.322259
# F1 racing                            8        2.657807
# auto racing                          7        2.325581
# tennis                               5        1.661130
# F1 Motorsports                       5        1.661130
# motorcycle gp                        4        1.328904
# NFL                                  3        0.996678
# Baseball                             3        0.996678
# NASCAR                               3        0.996678
# baseball                             3        0.996678
# Ice Hockey                           2        0.664452
# Auto Racing (Nascar)                 2        0.664452
# cycling                              1        0.332226
# American Football / Baseball         1        0.332226
# Hockey                               1        0.332226
# ice hockey                           1        0.332226
# NBA                                  1        0.332226
# Auto racing                          1        0.332226
# MMA                                  1        0.332226
# Estatísticas Descritivas
#              Sport
# count          301
# unique          29
# top     Basketball
# freq            54
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Relatório da Coluna: Year  ==*==*==*==
#
#
# Tipo: int64
# Valores nulos: 0
# valores únicos: 30
# Distribuição percentual de valores nulos: 0.00%
# Distribuição percentual dos valores únicos: 9.97%
#
#
# Listagem dos valores únicos e quantas vezes aparecem
#       count
# Year
# 2002     11
# 1990     10
# 2007     10
# 2019     10
# 2018     10
# 2017     10
# 2016     10
# 2015     10
# 2014     10
# 2013     10
# 2012     10
# 2011     10
# 2010     10
# 2009     10
# 2008     10
# 2006     10
# 1991     10
# 2005     10
# 2004     10
# 2003     10
# 2000     10
# 1999     10
# 1998     10
# 1997     10
# 1996     10
# 1995     10
# 1994     10
# 1993     10
# 1992     10
# 2020     10
# Distribuição dos valores por percentual:
#       Contagem  Percentual (%)
# Year
# 2002        11        3.654485
# 1990        10        3.322259
# 2007        10        3.322259
# 2019        10        3.322259
# 2018        10        3.322259
# 2017        10        3.322259
# 2016        10        3.322259
# 2015        10        3.322259
# 2014        10        3.322259
# 2013        10        3.322259
# 2012        10        3.322259
# 2011        10        3.322259
# 2010        10        3.322259
# 2009        10        3.322259
# 2008        10        3.322259
# 2006        10        3.322259
# 1991        10        3.322259
# 2005        10        3.322259
# 2004        10        3.322259
# 2003        10        3.322259
# 2000        10        3.322259
# 1999        10        3.322259
# 1998        10        3.322259
# 1997        10        3.322259
# 1996        10        3.322259
# 1995        10        3.322259
# 1994        10        3.322259
# 1993        10        3.322259
# 1992        10        3.322259
# 2020        10        3.322259
# Estatísticas Descritivas
#               Year
# count   301.000000
# mean   2005.122924
# std       9.063563
# min    1990.000000
# 25%    1997.000000
# 50%    2005.000000
# 75%    2013.000000
# max    2020.000000
#  ______________________________________________________________________________
#
#
#  ==*==*==*== Relatório da Coluna: earnings ($ million)  ==*==*==*==
#
#
# Tipo: float64
# Valores nulos: 0
# valores únicos: 198
# Distribuição percentual de valores nulos: 0.00%
# Distribuição percentual dos valores únicos: 65.78%
#
#
# Listagem dos valores únicos e quantas vezes aparecem
#                       count
# earnings ($ million)
# 40.0                      7
# 35.0                      7
# 23.0                      6
# 28.0                      6
# 33.0                      5
# ...                     ...
# 24.5                      1
# 21.0                      1
# 78.0                      1
# 30.5                      1
# 59.1                      1
#
# [198 rows x 1 columns]
# Distribuição dos valores por percentual:
#                       Contagem  Percentual (%)
# earnings ($ million)
# 40.0                         7        2.325581
# 35.0                         7        2.325581
# 23.0                         6        1.993355
# 28.0                         6        1.993355
# 33.0                         5        1.661130
# ...                        ...             ...
# 24.5                         1        0.332226
# 21.0                         1        0.332226
# 78.0                         1        0.332226
# 30.5                         1        0.332226
# 59.1                         1        0.332226
#
# [198 rows x 2 columns]
# Estatísticas Descritivas
#        earnings ($ million)
# count            301.000000
# mean              45.516279
# std               33.525337
# min                8.100000
# 25%               24.000000
# 50%               39.000000
# 75%               59.400000
# max              300.000000
#  ______________________________________________________________________________

# %% [markdown]
# Chama apenas o relatório geral do arquivo, sem a análise coluna por coluna

# %%
relatorio.relatotio_geral()

# %% [markdown]
# Chama apenas o relatório coluna por coluna, sem a análise geral

# %%
relatorio.relatorio_colunas()

# %% [markdown]
# Exporta o relatório para um arquivo PDF, com input do local onde salvar o arquivo

# %%
relatorio.exportar_relatorio()
